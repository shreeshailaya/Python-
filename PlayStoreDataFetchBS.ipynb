# %% [markdown]
# <a href="https://colab.research.google.com/github/shreeshailaya/Python-/blob/master/PlayStoreDataFetchBS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

pkgname=input('Enter package name:-  ')
blink='https://play.google.com/store/apps/details?id='
url=blink+pkgname


headers={
    "User-Agent":'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:68.0) Gecko/20100101 Firefox/68.0'
}


page=requests.get(url, headers=headers)
soup=BeautifulSoup(page.content,'html.parser')

def titleFetch():
  title=soup.title.text
  print('Title:-', title)

def decFetch(): 
  for e in soup.findAll('br'):
    e.extract()
  for f in soup.findAll('b'):
    f.extract()
  
  for g in soup.findAll('a'):
    g.extract()

  info=soup.find('div',{'jsname':'sngebd'})
  print('Description:-',info.prettify()[0:2000])
  

def imgFetch():
  image=soup.find('img',{'class':'T75of sHb2Xb'})
  imgurl=image["src"]
  img=mpimg.imread(imgurl)
  imgplot = plt.imshow(img)
  plt.show()


def authFetch():
  auth=soup.find('a',{'class':'hrTbp R8zArc'})
  auth1=auth.get_text()
  print('Developer:',auth1)

def ndownldsFetch():
  ndown=soup.findAll('span',{'class':'htlgb'})[5]
  ndown1=ndown
  for f in ndown1('span'):
    f.extract()


  print('No Of Downloads:- ' ,ndown1)
  


ndownldsFetch()
titleFetch()
authFetch()
imgFetch()
decFetch()
# Out:
# Enter package name:-  com.frogmind.badlandbrawl
# No Of Downloads:-  <span class="htlgb">5,000,000+</span>
# Title:- Badland Brawl - Apps on Google Play
# Developer: Frogmind
# Description:- <div jsname="sngebd">
#  🏆 - Google Play Best of 2018 Winner: Most Competitive category
#  🏆 - Tabby Mobile Game Awards Winner 2018
#  🏆 - Samsung Galaxy Apps Winner: Best Multiplayer Game 2019
#  💣🔥
#  of epic action with easy-to-play but hard-to-master physics-based gameplay.
#  Sling your Clones onto the battlefield! Master your timing and aim and build crazy tactics &amp; devastating chain reactions! Combine dozens of clones into a brilliantly tactical onslaught and take down the opponent's tower!
#  ⚔ Battle friends and other players around the world in real-time Brawls
#  🔥 Fun, intuitive and unique physics-based gameplay
#  💣 Build crazy chain reactions to outwit and overwhelm your opponents
#  🏆 Award-winning BADLAND universe with dozens of new characters
#  🥚 Unlock mysterious BADLAND eggs to collect and upgrade crazy clone characters
#  🏹 Construct tactical brawl parties and learn to use your Clones in clever ways
#  👑 Progress through dozens of Lands and go all the way to the top!
#  💬 Join or create a Tribe, share Clones and build your own Brawl community
#  ⚔ Challenge Tribemates and friends to private duels
#  🎦 Learn new tactics by watching the best Brawls from BadTube (in-game)
#  A network connection is required.
#  Are you having problems? Visit https://frogmind.helpshift.com or contact us in game by going to Settings &gt; Help and Support.
#  http://frogmind.com/privacy-policy/
#  http://frogmind.com/tos/
#  http://frogmind.com/parents/
#  PLEASE NOTE! Badland Brawl is free to download and free to play, however, some game items can also be purchased for real money. If you don't want to use this feature, you can disable in-app purchases from your device's settings. Under our Terms of Service and Privacy Policy, you need be at least 13 years of age to play or download Badland Brawl.
#  Facebook -
#  Twitter -
#  Discord - https://discord.gg/badland
# </div>
